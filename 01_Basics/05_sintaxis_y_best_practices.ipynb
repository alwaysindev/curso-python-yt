# %% [markdown]
# # 05 — Sintaxis y buenas prácticas
# Objetivos:
# - Repasar PEP 8 esencial.
# - Comentarios útiles y `print` vs logging ligero.
# - Limpieza en notebooks.
# - Checklist + mini-quiz + retos.

# %% [markdown]
# ## PEP 8
# - Nombres: `snake_case` para variables/funciones; `UPPER_CASE` para constantes; `CamelCase` para clases.
# - Longitud de línea ≈ 79–99 chars.
# - 4 espacios de indentación (no tabuladores).
# - Espacios: `a = 1`, no `a=1`.
# - Comillas: elige una (`'` o `"`) y sé consistente.

# %% [markdown]
# ## Comentarios útiles
# - Explican el **porqué**, no lo obvio.
# - Manténlos actualizados; mejor poco y bueno.

# %%
tasa_interes = 0.05  # Usamos 5% por política interna 2024

# %% [markdown]
# ## `print` vs logging (ligero)
# - `print()` para aprendizaje/demos.
# - En proyectos, usa `logging` para niveles y control.

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.info("Proceso iniciado")
# Out:
# INFO:root:Proceso iniciado

# %% [markdown]
# ## Checklist
# - [ ] Nombres claros (`snake_case`).
# - [ ] Líneas cortas y legibles.
# - [ ] Comentarios solo donde aporten.

# %% [markdown]
# ## Mini-quiz (10 preguntas)
# 1. ¿`None == 0` es True o False?
# 2. ¿Qué devuelve `bool("")`?
# 3. ¿Qué hace `int("3.0")`?
# 4. ¿Qué tipo es `type(True + 1)`?
# 5. ¿`set([1,1,2])` contiene cuántos elementos?
# 6. ¿`del lista[0]` devuelve el valor eliminado?
